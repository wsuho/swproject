# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "cHD9pPY6pssTuar5LXwc"
client_secret = "yOJryxOkyp"

query = urllib.parse.quote(input("검색어 입력: "))
idx = 0
display = 5
start = 1
end = 10

web_df = pd.DataFrame(columns=("Title", "LInk", "Description")) 

for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/webkr?query=" + query\
    + "&display=" + str(display)\
    + "&start=" + str(start_index)

    request = urllib. request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib. request.urlopen(request)
    rescode = response. getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json. loads(response_body.decode('utf-8'))
        items =  response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re. compile('<.*?>')
            title = re. sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re. sub(remove_tag,'',items[item_index]['description'])
            web_df. loc[idx] = [title, link, description]
            idx += 1
    else:
        print("Error Code:" + rescode)

web_df
# Out:
# 검색어 입력: 컴퓨터
#                                      Title  \
# 0                               컴퓨터 - 나무위키
# 1                                  수험서/자격증
# 2                  Dell 공식 사이트 | Dell 대한민국
# 3                    컴퓨존 - 컴퓨터, 전자제품 종합쇼핑몰
# 4                              가전·컴퓨터 - 티몬
# 5                            분류:컴퓨터 - 나무위키
# 6                              YJMODx영재컴퓨터
# 7                             컴퓨터공학 - 나무위키
# 8  컴퓨터게시판은 컴퓨터에 관한 정보 교류를 위한 곳입니다. - 오늘의유머
# 9                  텐바이텐 10X10 : 검색결과 - 컴퓨터
#
#                                                 LInk  \
# 0    https://namu.wiki/w/%EC%BB%B4%ED%93%A8%ED%84%B0
# 1  http://browse.gmarket.co.kr/list?category=3000...
# 2  https://www.dell.com/ko-kr?c=kr&l=ko&s=,gen&~c...
# 3                       https://www.compuzone.co.kr/
# 4            http://www.tmon.co.kr/deallist/57000000
# 5  https://namu.wiki/w/%EB%B6%84%EB%A5%98:%EC%BB%...
# 6                  https://www.youngjaecomputer.com/
# 7  https://namu.wiki/w/%EC%BB%B4%ED%93%A8%ED%84%B...
# 8  http://www.todayhumor.co.kr/board/list.php?tab...
# 9  https://www.10x10.co.kr/search/search_result.a...
#
#                                          Description
# 0          Computer 이진법을 이용하여 논리 연산, 저장을 수행하는 전자 기계.
# 1  엑셀 교육 기초 실무 책 교재 보다 좋은 강좌 USB컴퓨터기초/인터넷/아래한글/엑셀...
# 2  델 본사 공식 온라인 쇼핑몰에서는 최신기술의 Dell 정품 제품을 다양한 온라인 프...
# 3              PC,노트북,컴퓨터부품,가전제품,주변기기,소모품,사무용품,케이블 등
# 4           1/2 전체 7,512,220개 포토리뷰 상품의 포토리뷰를 확인해보세요!
# 5         이 분류에 대한 설명은 컴퓨터 문서나 컴퓨터 관련 정보 문서를 참고하십시오.
# 6                 컴퓨터 및 주변기기, 조립PC 전문 쇼핑몰, 모니터 전산소모품
# 7  電算學 / Computer Science &amp; Engineering(CSE) ...
# 8  370617 컴퓨터 판매하려는데 얼마가 적당할까요? [4] hong2 22/06/0...
# 9  컴퓨터 노트북 키보드 모니터 컴퓨터책상 컴퓨터 메모 텐바이텐배송 산리오 (4,586...

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "cHD9pPY6pssTuar5LXwc"
client_secret = "yOJryxOkyp"

query = urllib.parse.quote(input("검색어 입력: "))
idx = 0
display = 5
start = 1
end = 10
sort = "sim"

news_df = pd.DataFrame(columns=("Title", "LInk","Original Link", "Description","Publication Date")) 

for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/news?query=" + query\
    + "&display=" + str(display)\
    + "&start=" + str(start_index)\
    +"&sort=" +sort

    request = urllib. request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib. request.urlopen(request)
    rescode = response. getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json. loads(response_body.decode('utf-8'))
        items =  response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re. compile('<.*?>')
            title = re. sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            original_link = items[item_index]['originallink']
            description = re. sub(remove_tag,'',items[item_index]['description'])
            pub_date = items[item_index]['pubDate']
            news_df. loc[idx] = [title, original_link, link, description, pub_date]
            idx += 1
    else:
        print("Error Code:" + rescode)

news_df
# Out:
# 검색어 입력: 컴퓨터
#                                          Title  \
# 0                           컴퓨터도 실내 대기오염 물질 배출
# 1                 컴퓨터 오래 사용하면 목이 칼칼한 이유, 알고보니…
# 2               컴퓨터 더운 바람 이럴수가…석유 배기가스 성분과 같았다
# 3            UNIST, 과열된 컴퓨터에서도 대기오염물질 배출 사실 규명
# 4        컴퓨터에서 산불 오염물질 나온다…&quot;환기 자주해야&quot;
# 5  “요즘 방 안에서도 목이 간지러웠던 이유가…” 컴퓨터에서도 대기오염물질 ...
# 6  UNIST &quot;컴퓨터 부품의 오염물질이 배출돼 실내공기 오염&quot;
# 7                      과열된 컴퓨터에서 공장굴뚝 대기오염물질이?
# 8               공장 굴뚝의 대기오염 물질, 사무실 컴퓨터에서도 나온다
# 9    과열된 컴퓨터에서 대기오염물질 배출… &quot;자주 환기 해야&quot;
#
#                                                 LInk  \
# 0        https://zdnet.co.kr/view/?no=20220613104011
# 1  https://www.seoul.co.kr/news/newsView.php?id=2...
# 2  http://news.mt.co.kr/mtview.php?no=20220613104...
# 3  http://www.newsis.com/view/?id=NISX20220613_00...
# 4  https://www.khan.co.kr/environment/environment...
# 5  http://news.heraldcorp.com/view.php?ud=2022061...
# 6             https://www.news1.kr/articles/?4710023
# 7           https://www.nocutnews.co.kr/news/5770815
# 8  https://www.chosun.com/economy/science/2022/06...
# 9  https://hankookilbo.com/News/Read/A20220613125...
#
#                                        Original Link  \
# 0  https://n.news.naver.com/mnews/article/092/000...
# 1  https://n.news.naver.com/mnews/article/081/000...
# 2  https://n.news.naver.com/mnews/article/008/000...
# 3  https://n.news.naver.com/mnews/article/003/001...
# 4  https://n.news.naver.com/mnews/article/032/000...
# 5  https://n.news.naver.com/mnews/article/016/000...
# 6  https://n.news.naver.com/mnews/article/421/000...
# 7  https://n.news.naver.com/mnews/article/079/000...
# 8  https://n.news.naver.com/mnews/article/023/000...
# 9  https://n.news.naver.com/mnews/article/469/000...
#
#                                          Description  \
# 0  가정이나 직장의 컴퓨터가 실내에 대기오염 물질을 배출하는 것으로 나타났다. UNIS...
# 1  컴퓨터를 오래 사용하다 보면 이유 없이 목이 칼칼한 느낌을 받을 때가 있다. 미세먼...
# 2  [컴퓨터, 다환방향족탄화수소(PAHs) 배출 잘 분해 안 돼 '유해 대기오염물질'로...
# 3  기사내용 요약 환기·적정 냉각 온도 유지 등 중요…UNIST 최성득 교수팀 Buil...
# 4  컴퓨터에서도 산불이나 자동차, 공장처럼 대기오염물질이 방출된다는 연구 결과가 나왔다...
# 5  “요즘 방 안에서도 코가 맵고 기침이 자주 나왔는데 원인이 컴퓨터 때문이었다?” 공...
# 6  공장 굴뚝에서 배출되는 대기오염물질이 과열된 컴퓨터에서도 배출되는 것으로 확인됐다....
# 7  공장 굴뚝에서 배출되는 대기오염 물질이 과열된 컴퓨터에서도 나온다는 연구 결과가 나...
# 8  공장 굴뚝에서 배출되는 대기오염물질이 사무실 컴퓨터에서도 나오는 것으로 확인됐다. ...
# 9  과열된 컴퓨터에서도 공장 굴뚝과 같은 대기오염물질이 배출되는 것으로 나타났다. 울산...
#
#                   Publication Date
# 0  Mon, 13 Jun 2022 12:01:00 +0900
# 1  Mon, 13 Jun 2022 14:22:00 +0900
# 2  Mon, 13 Jun 2022 12:00:00 +0900
# 3  Mon, 13 Jun 2022 12:00:00 +0900
# 4  Mon, 13 Jun 2022 12:02:00 +0900
# 5  Mon, 13 Jun 2022 13:56:00 +0900
# 6  Mon, 13 Jun 2022 13:16:00 +0900
# 7  Mon, 13 Jun 2022 13:55:00 +0900
# 8  Mon, 13 Jun 2022 12:01:00 +0900
# 9  Mon, 13 Jun 2022 13:42:00 +0900

# %%
임기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15008/1982959319.py in <module>
# ----> 1 임기
#
# NameError: name '임기' is not defined
